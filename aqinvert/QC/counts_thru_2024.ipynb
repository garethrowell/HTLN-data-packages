# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\GRowell\HTLN-data-packages-data\aqinvert\CountData.csv"
df = pd.read_csv(path)
print(df.head())
# Out:
#                  ParkName ParkCode  Season      LocationID     StreamName  \
# 0  Buffalo National River     BUFF    2005  BUFFRMINVEBM02  Buffalo River
# 1  Buffalo National River     BUFF    2005  BUFFRMINVEBM02  Buffalo River
# 2  Buffalo National River     BUFF    2005  BUFFRMINVEBM02  Buffalo River
# 3  Buffalo National River     BUFF    2005  BUFFRMINVEBM02  Buffalo River
# 4  Buffalo National River     BUFF    2005  BUFFRMINVEBM02  Buffalo River
#
#   TributaryName              EventID  RiffleNo Replicate       Taxon_EML  ...  \
# 0           NaN  BUFFRMINVE2005NOV29         1         L   Hydrachnidiae  ...
# 1           NaN  BUFFRMINVE2005NOV29         1         L   Entomobryidae  ...
# 2           NaN  BUFFRMINVE2005NOV29         1         L     Macronychus  ...
# 3           NaN  BUFFRMINVE2005NOV29         1         L  Microcylloepus  ...
# 4           NaN  BUFFRMINVE2005NOV29         1         L       Stenelmis  ...
#
# ...

# %%
df.dtypes
# Out:
# ParkName                   object
# ParkCode                   object
# Season                      int64
# LocationID                 object
# StreamName                 object
# TributaryName              object
# EventID                    object
# RiffleNo                    int64
# Replicate                  object
# Taxon_EML                  object
# TaxonCode                  object
# TSN                       float64
# Phylum                     object
# Class                      object
# Order                      object
# Family                     object
# Subfamily                  object
# Genus                      object
# ToleranceValue            float64
# FunctionalFeedingGroup     object
# LargeRare                   int64
# RepCount                    int64
# PerSample_LREq1           float64
# PerSample_Inv             float64
# RepCount_Calc             float64
# Note                       object
# dtype: object

# %%
sorted(df['ParkName'].unique())
# Out:
# ['Buffalo National River',
#  'Effigy Mounds National Monument',
#  'George Washington Carver National Monument',
#  'Herbert Hoover National Historic Site',
#  'Homestead National Monument',
#  'Hot Springs National Park',
#  'Ozark National Scenic Riverways - RIVERS',
#  'Ozark National Scenic Riverways - SPRINGS',
#  'Pea Ridge National Military Park',
#  'Pipestone National Monument',
#  'Tallgrass Prairie National Preserve',
#  'Wilsons Creek National Battlefield']

# %%
sorted(df['ParkCode'].unique())
# Out:
# ['BUFF',
#  'EFMO',
#  'GWCA',
#  'HEHO',
#  'HOME',
#  'HOSP',
#  'OZAR',
#  'OZRS',
#  'PERI',
#  'PIPE',
#  'TAPR',
#  'WICR']

# %%
df['Season'].unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %%
sorted(df["LocationID"].unique())
# Out:
# ['BUFFRMINVEBM01',
#  'BUFFRMINVEBM02',
#  'BUFFRMINVEBM03',
#  'BUFFRMINVEBM04',
#  'BUFFRMINVEBM05',
#  'BUFFRMINVEBM06',
#  'BUFFRMINVEBT01',
#  'BUFFRMINVEBT03',
#  'BUFFRMINVEBT04',
#  'BUFFRMINVEBT05',
#  'BUFFRMINVEBT06',
#  'BUFFRMINVEBT07',
#  'BUFFRMINVEBT08',
#  'BUFFRMINVEBT09',
#  'BUFFRMINVEBT10',
#  'BUFFRMINVEBT11',
#  'BUFFRMINVEBT13',
#  'BUFFRMINVEBT14',
#  'BUFFRMINVEBT15',
#  'BUFFRMINVEBT16',
#  'BUFFRMINVEBT17',
#  'BUFFRMINVEBT19',
#  'BUFFRMINVEBT20',
#  'BUFFRMINVEBT22',
#  'BUFFRMINVEBT23',
#  'BUFFRMINVEBT24',
#  'BUFFRMINVEBT25',
#  'BUFFRMINVEBT27',
#  'BUFFRMINVEBT30',
#  'BUFFRMINVEBT31',
#  'BUFFRMINVEBT33',
#  'EFMOAqubug01',
#  'GWCAAQUBUG01',
#  'GWCAAQUBUG02',
#  'GWCAAQUBUG03',
#  'GWCAAquBug01',
#  'GWCAAquBug02',
#  'GWCAAquBug03',
#  'HEHOAqubug01',
#  'HOMEAQUBUG01',
#  'HOMEAQUBUG02',
#  'HOMEAquBug01',
#  'HOMEAquBug02',
#  'HOSPAqubug01',
#  'HOSPAqubug02',
#  'OZARRMINVECM01',
#  'OZARRMINVECM02',
#  'OZARRMINVECM03',
# ...

# %%
sorted(df['StreamName'].unique())
# Out:
# ['Alley Spring',
#  'Big Spring',
#  'Blue Spring',
#  'Buffalo River',
#  'Bull Bayou',
#  'Carver Branch',
#  'Current River',
#  'Dousman Creek',
#  'Fox Creek',
#  'Gulpha Creek',
#  'Harkins Branch',
#  'Hoover Creek',
#  'Jacks Fork',
#  'Lee Creek',
#  'Lower Wilson Creek',
#  'Middle Pipestone Creek',
#  'North Cub Creek',
#  'Palmer Creek',
#  'Phillips Spring',
#  'Pratt Creek',
#  'Pulltite Spring',
#  'Round Spring',
#  "Skegg's Branch",
#  'Terrell Creek',
#  'Upper Pipestone Creek',
#  'Upper Wilson Creek',
#  'Welch Spring',
#  'West Cub Creek',
#  'Williams Branch',
#  'Winton Spring Branch']

# %%
df["TributaryName"] = df["TributaryName"].astype(str)
sorted(df["TributaryName"].unique())
# Out:
# ['Bear Creek',
#  'Big Creek (U)',
#  'Big East Creek',
#  'Big West Creek',
#  'Blair Creek',
#  'Calf Creek',
#  'Carr Creek',
#  'Cecil Creek',
#  'Clabber Creek',
#  'Davis Creek',
#  'Flat Rock Hollow',
#  'Glade Creek',
#  'Hickory Creek',
#  'Leatherwood Creek',
#  'Lick Creek',
#  'Little Buffalo',
#  'Middle Creek',
#  'Mill Branch',
#  'Mill Creek',
#  'Mill Creek (U)',
#  'Panther Creek',
#  'Powdermill Creek',
#  'Prairie Hollow',
#  'Richland Creek',
#  'Rock Creek',
#  'Rocky Creek',
#  'Rogers Creek',
#  'Shafer Spring',
#  'Shawnee Creek',
#  'Sinking Creek',
#  'Smith Creek',
#  'Sneeds Creek',
#  'Spring Creek',
#  'Stewart Creek',
#  'Sutton Creek',
#  'Thompson Creek',
#  'Vanishing Creek',
#  'Water Branch',
#  'Water Creek',
#  'Wells Creek',
#  'Whiteley Creek',
#  'nan']

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMINVE2005DEC01',
#  'BUFFRMINVE2005DEC14',
#  'BUFFRMINVE2005DEC20',
#  'BUFFRMINVE2005NOV29',
#  'BUFFRMINVE2005NOV30',
#  'BUFFRMINVE2007DEC03',
#  'BUFFRMINVE2007DEC04',
#  'BUFFRMINVE2007Dec03',
#  'BUFFRMINVE2007Dec04',
#  'BUFFRMINVE2007FEB09',
#  'BUFFRMINVE2007FEB21',
#  'BUFFRMINVE2007FEB22',
#  'BUFFRMINVE2007JAN04',
#  'BUFFRMINVE2007JAN05',
#  'BUFFRMINVE2007JAN08',
#  'BUFFRMINVE2007JAN09',
#  'BUFFRMINVE2007JAN20',
#  'BUFFRMINVE2007Nov26',
#  'BUFFRMINVE2007Nov27',
#  'BUFFRMINVE2007Nov28',
#  'BUFFRMINVE2007Nov30',
#  'BUFFRMINVE2008Dec02',
#  'BUFFRMINVE2008Dec04',
#  'BUFFRMINVE2008Dec05',
#  'BUFFRMINVE2008Dec10',
#  'BUFFRMINVE2008Dec11',
#  'BUFFRMINVE2008Jan22',
#  'BUFFRMINVE2008Jan23',
#  'BUFFRMINVE2009Dec07',
#  'BUFFRMINVE2009Dec08',
#  'BUFFRMINVE2009Dec14',
#  'BUFFRMINVE2009Dec15',
#  'BUFFRMINVE2009Dec16',
#  'BUFFRMINVE2009Feb18',
#  'BUFFRMINVE2009Jan08',
#  'BUFFRMINVE2010Dec01',
#  'BUFFRMINVE2010Jan11',
#  'BUFFRMINVE2010Jan12',
# ...

# %%
df['RiffleNo'].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  6, 51, 52,  7, 61, 62,  8, 10])

# %%
df['Replicate'].unique()
# Out:
# array(['L', 'M', 'R', 'H', 'm'], dtype=object)

# %%
sorted(df['Taxon_EML'].unique())  # lowest taxon category - used to generate the EML taxonomy
# Out:
# ['Acentrella',
#  'Acerpenna',
#  'Acroneuria',
#  'Agabini',
#  'Agabus',
#  'Agapetus',
#  'Agnetina',
#  'Allocapnia',
#  'Alloperla',
#  'Ameletus',
#  'Amnicola',
#  'Amphinemura',
#  'Anafroptilum',
#  'Anthopotamus',
#  'Antocha',
#  'Aquarius',
#  'Argia',
#  'Atherix',
#  'Atrichopogon',
#  'Baetidae',
#  'Baetis',
#  'Baetisca',
#  'Berosus',
#  'Bivalvia',
#  'Boyeria',
#  'Brachycentrus',
#  'Branchiobdellidae',
#  'Caecidotea',
#  'Caenis',
#  'Callibaetis',
#  'Caloparyphus',
#  'Calopteryx',
#  'Ceraclea',
#  'Ceratopogoninae',
#  'Cernotina',
#  'Chauliodes',
#  'Chelifera',
#  'Cheumatopsyche',
#  'Chimarra',
#  'Chloroperlidae',
#  'Chlorotabanus',
#  'Chrysops',
#  'Cladocera',
#  'Climacia',
#  'Clinocera',
#  'Clioperla',
#  'Coenagrionidae',
#  'Corbicula',
#  'Corixidae',
#  'Corydalus',
#  'Crambidae',
#  'Crangonyctidae',
#  'Crangonyx',
#  'Cryptolabis',
#  'Culex',
#  'Cyclonaias',
#  'Cyrnellus',
#  'Dibusa',
#  'Dicranota',
#  'Dineutus',
# ...

# %%
sorted(df['TaxonCode'].unique())
# Out:
# ['AESHBO',
#  'AMELAM',
#  'AMNIAM',
#  'ASELCA',
#  'ASELLI',
#  'ATHEAT',
#  'BAET',
#  'BAETAC',
#  'BAETAN',
#  'BAETAP',
#  'BAETBA',
#  'BAETCA',
#  'BAETFA',
#  'BAETIS',
#  'BAETPA',
#  'BAETPL',
#  'BAETPR',
#  'BATCBA',
#  'BIVAL',
#  'BRACHBR',
#  'BRACHMI',
#  'BRAN',
#  'CAENCA',
#  'CALOCA',
#  'CALOHE',
#  'CAMBFA',
#  'CAPNAL',
#  'CAPNPA',
#  'CERA',
#  'CERAAT',
#  'CERAFO',
#  'CHLO',
#  'CHLOAL',
#  'CHLOHA',
#  'CLAD',
#  'COEN',
#  'COENAR',
#  'COENEN',
#  'COENIS',
#  'CORI',
#  'CORISI',
#  'CORYCH',
#  'CORYCO',
#  'CORYNI',
#  'CRAM',
#  'CRAMPA',
#  'CRAMPE',
#  'CRANBS',
#  'CRANCR',
#  'CRANST',
#  'CULICU',
#  'CYRECO',
#  'DIXIDI',
#  'DOLI',
#  'DRYOHE',
#  'DUGEGI',
#  'DYTIA',
#  'DYTIAG',
#  'DYTIHG',
#  'DYTIIO',
#  'ELMI',
#  'ELMIDU',
#  'ELMIMA',
#  'ELMIMI',
#  'ELMIOP',
#  'ELMIST',
#  'EMMEFO',
#  'EMPICH',
#  'EMPICL',
#  'EMPIHE',
#  'EMPIOR',
#  'EMPITR',
#  'ENTO',
#  'EPHE',
#  'EPHEEH',
#  'EPHEEP',
#  'EPHEEU',
#  'EPHEHE',
# ...

# %%
df['TSN'].unique()
# Out:
# array([ 8.276900e+04,  9.964300e+04,  1.142120e+05,  1.141460e+05,
#         1.140950e+05,  1.140870e+05,  1.140700e+05,  1.267740e+05,
#         1.014780e+05,  1.013240e+05,  1.005040e+05,  1.005070e+05,
#         1.010410e+05,  1.014050e+05,  1.021390e+05,  1.016640e+05,
#         1.031060e+05,  1.027890e+05,  1.154080e+05,  1.152730e+05,
#         8.138500e+04,  7.656900e+04,  7.165400e+04,  1.309340e+05,
#         1.150330e+05,  1.028400e+05,  1.141770e+05,  1.267030e+05,
#         1.006760e+05,  1.017380e+05,  1.141260e+05,  1.007130e+05,
#         1.029420e+05,  1.140060e+05,  1.190370e+05,  1.150860e+05,
#         1.029000e+05,  9.377300e+04,  1.029170e+05,  1.156410e+05,
#         1.363270e+05,  1.170160e+05,  1.014940e+05,  1.015930e+05,
#         1.273380e+05,  1.020770e+05,  1.165480e+05,  1.153350e+05,
#         7.659100e+04,  5.685590e+05,  1.176820e+05,  1.012320e+05,
#         1.154530e+05,  1.029140e+05,  1.128120e+05,  9.402500e+04,
# ...

# %%
sorted(df['Phylum'].unique())
# Out:
# ['Annelida', 'Arthropoda', 'Cnidaria', 'Mollusca', 'Platyhelminthes']

# %%
sorted(df['Class'].unique())
# Out:
# ['Arachnida',
#  'Bivalvia',
#  'Branchiopoda',
#  'Clitellata',
#  'Collembola',
#  'Gastropoda',
#  'Hydrozoa',
#  'Insecta',
#  'Malacostraca',
#  'Rhabditophora']

# %%
df["Order"] = df["Order"].astype(str)
sorted(df['Order'].unique())
# Out:
# ['"Hirudinida"',
#  'Amphipoda',
#  'Anthoathecata',
#  'Architaenioglossa',
#  'Arhynchobdellida',
#  'Branchiobdellida',
#  'Coleoptera',
#  'Decapoda',
#  'Diplostraca',
#  'Diptera',
#  'Entomobryomorpha',
#  'Ephemeroptera',
#  'Hemiptera',
#  'Isopoda',
#  'Lepidoptera',
#  'Littorinimorpha',
#  'Megaloptera',
#  'Neotaenioglossa',
#  'Neuroptera',
#  'Odonata',
#  'Orthoptera',
#  'Plecoptera',
#  'Poduromorpha',
#  'Rhynchobdellida',
#  'Symphypleona',
#  'Trichoptera',
#  'Tricladida',
#  'Trombidiformes',
#  'Unionida',
#  'Venerida',
#  'Veneroida',
#  'nan']

# %%
df["Family"] = df["Family"] .astype(str)

sorted(df["Family"].unique())
# Out:
# ['"Cladocera"',
#  '"Hydrachnidiae"',
#  'Aeshnidae',
#  'Ameletidae',
#  'Amnicolidae',
#  'Asellidae',
#  'Athericidae',
#  'Baetidae',
#  'Baetiscidae',
#  'Brachycentridae',
#  'Branchiobdellidae',
#  'Caenidae',
#  'Calopterygidae',
#  'Cambaridae',
#  'Capniidae',
#  'Ceratopogonidae',
#  'Chloroperlidae',
#  'Coenagrionidae',
#  'Corixidae',
#  'Corydalidae',
#  'Crambidae',
#  'Crangonyctidae',
#  'Culicidae',
#  'Cyrenidae',
#  'Dixidae',
#  'Dolichopodidae',
#  'Dryopidae',
#  'Dugesiidae',
#  'Dytiscidae',
#  'Elmidae',
#  'Emmericiidae',
#  'Empididae',
#  'Entomobryidae',
#  'Ephemerellidae',
#  'Ephemeridae',
#  'Ephydridae',
#  'Erpobdellidae',
#  'Gammaridae',
#  'Gerridae',
#  'Glossiphoniidae',
#  'Glossosomatidae',
#  'Gomphidae',
#  'Gyrinidae',
#  'Haliplidae',
#  'Hebridae',
#  'Helicopsychidae',
#  'Heptageniidae',
#  'Hyalellidae',
#  'Hydraenidae',
#  'Hydridae',
#  'Hydrobiidae',
#  'Hydrophilidae',
#  'Hydropsychidae',
#  'Hydroptilidae',
# ...

# %%
df["Subfamily"] = df["Subfamily"].astype(str)
sorted(df['Subfamily'].unique())
# Out:
# ['Agabinae', 'Ceratopogoninae', 'Forcipomyiinae', 'nan']

# %%
df["Genus"] = df["Genus"].astype(str)
sorted(df['Genus'].unique())
# Out:
# ['"Agabini"',
#  '"Pericomaini"',
#  '"Psychodini"',
#  '(Stygobromus/Bactrurus)',
#  'Acentrella',
#  'Acerpenna',
#  'Acroneuria',
#  'Agabus',
#  'Agapetus',
#  'Agnetina',
#  'Allocapnia',
#  'Alloperla',
#  'Ameletus',
#  'Amnicola',
#  'Amphinemura',
#  'Anafroptilum',
#  'Anthopotamus',
#  'Antocha',
#  'Aquarius',
#  'Argia',
#  'Atherix',
#  'Atrichopogon',
#  'Baetis',
#  'Baetisca',
#  'Berosus',
#  'Boyeria',
#  'Brachycentrus',
#  'Caecidotea',
#  'Caenis',
#  'Callibaetis',
#  'Caloparyphus',
#  'Calopteryx',
#  'Ceraclea',
#  'Cernotina',
#  'Chauliodes',
#  'Chelifera (Metachela)',
#  'Cheumatopsyche',
#  'Chimarra',
#  'Chlorotabanus',
#  'Chrysops',
#  'Climacia',
#  'Clinocera',
#  'Clioperla',
#  'Corbicula',
#  'Corydalus',
#  'Crangonyx',
#  'Cryptolabis',
#  'Culex',
#  'Cyclonaias',
#  'Cyrnellus',
#  'Dibusa',
#  'Dicranota',
#  'Dineutus',
#  'Diplectrona',
#  'Dixa',
#  'Dromogomphus',
#  'Dubiraphia',
#  'Ectopria',
#  'Elimia',
#  'Ellipes',
# ...

# %%
cols = ['ToleranceValue'] 
df2 = df[(df[cols] > 0) & (df[cols] <= 10)]
df2.hist(column='ToleranceValue')
# Out:
# array([[<Axes: title={'center': 'ToleranceValue'}>]], dtype=object)

# %%
df["FunctionalFeedingGroup"] = df["FunctionalFeedingGroup"].astype(str)
sorted(df['FunctionalFeedingGroup'].unique())
# Out:
# ['C',
#  'C, F',
#  'C, He',
#  'C, Pr',
#  'C, Sc',
#  'C, Sh',
#  'C,F',
#  'C,He',
#  'C,Pr',
#  'C,SC',
#  'C,Sc',
#  'C,Sh',
#  'C,Sh,Sc',
#  'F',
#  'F,Sh',
#  'He, Pr',
#  'He,C',
#  'He,Pr',
#  'He,SC',
#  'Pa',
#  'Pa,Pr',
#  'Pr',
#  'Pr, C, Sh',
#  'Pr, F, Sh',
#  'SC',
#  'Sc',
#  'Sc, C, Sh, He',
#  'Sc,Sh',
#  'Sh',
#  'Sh, He',
#  'nan']

# %%
df['LargeRare'].unique()
# Out:
# array([0, 1])

# %%
df['RepCount'].unique()
# Out:
# array([   1,   27,    2,   10,   16,    9,   45,   29,   22,    7,   19,
#           3,   32,    5,    6,   35,   23,   50,    4,   21,   18,   54,
#          30,   48,   56,   49,   14,   72,   33,    8,   20,   17,   84,
#          28,   12,   64,   11,   25,   71,   44,   13,   15,   38,   67,
#          24,   51,   73,  165,   37,   66,   74,   97,   65,   58,   34,
#          96,   75,   42,  120,  109,  160,   47,   43,   80,  139,   39,
#          53,  128,  187,  250,   41,  159,   57,  279,  116,  208,  119,
#         112,  140,  150,  267,   61,  152,   26,  130,  217,  540,   40,
#         289,  219,   76,   83,   79,  146,   78,  133,  266,  101,  287,
#         204,  114,  376,  124,   99,   91,   77,   59,   85,  110,  107,
#         115,  137,  143,  108,  153,  265,   82,  938,  440,  144,   87,
#          62,  210,  415,  191,  252,   46,  106,   92,  127,   31,   60,
#          63,  224,  183,  147,   69,  182,   52,  240,   70,   89,  170,
# ...

# %%
cols = ['RepCount'] 
df2 = df[(df[cols] > 0) & (df[cols] <=10)]
df2.hist(column='RepCount')
# Out:
# array([[<Axes: title={'center': 'RepCount'}>]], dtype=object)

# %%
cols = ['RepCount'] 
df2 = df[(df[cols] > 10) & (df[cols] <= 100)]
df2.hist(column='RepCount')
# Out:
# array([[<Axes: title={'center': 'RepCount'}>]], dtype=object)

# %%
cols = ['RepCount'] 
df2 = df[(df[cols] > 100) & (df[cols] <= 1000)]
df2.hist(column='RepCount')
# Out:
# array([[<Axes: title={'center': 'RepCount'}>]], dtype=object)

# %%
cols = ['RepCount']
df2 = df[df[cols] > 1000]
df2.hist(column='RepCount')
# Out:
# array([[<Axes: title={'center': 'RepCount'}>]], dtype=object)

# %%
df.hist(column='PerSample_LREq1')
# Out:
# array([[<Axes: title={'center': 'PerSample_LREq1'}>]], dtype=object)

# %%
df.hist(column='PerSample_Inv')
# Out:
# array([[<Axes: title={'center': 'PerSample_Inv'}>]], dtype=object)

# %%
col = ['RepCount_Calc'] 
df2 = df[(df[col] > 0) & (df[col] <= 10)]
df2.hist(column='RepCount_Calc')
# Out:
# array([[<Axes: title={'center': 'RepCount_Calc'}>]], dtype=object)

# %%
col = ['RepCount_Calc'] 
df2 = df[(df[col] > 10) & (df[col] <= 100)]
df2.hist(column='RepCount_Calc')
# Out:
# array([[<Axes: title={'center': 'RepCount_Calc'}>]], dtype=object)

# %%
col = ['RepCount_Calc'] 
df2 = df[(df[col] > 100) & (df[col] <= 1000)]
df2.hist(column='RepCount_Calc')
# Out:
# array([[<Axes: title={'center': 'RepCount_Calc'}>]], dtype=object)

# %%
col = ['RepCount_Calc'] 
df2 = df[(df[col] > 1000) & (df[col] <= 10000)]
df2.hist(column='RepCount_Calc')
# Out:
# array([[<Axes: title={'center': 'RepCount_Calc'}>]], dtype=object)

# %%
col = ['RepCount_Calc'] 
df2 = df[(df[col] > 10000) & (df[col] <= 100000)]
df2.hist(column='RepCount_Calc')
# Out:
# array([[<Axes: title={'center': 'RepCount_Calc'}>]], dtype=object)

# %%
df["Note"] = df["Note"].astype(str)
sorted(df['Note'].unique())
# Out:
# ['1 in Ref Collection',
#  '1 in reference collection',
#  '1 is Maccafertium',
#  '1 mature nymph',
#  '1 specimen in RC.',
#  '1 with anal gills',
#  '10 are Maccafertium',
#  '10 are Maccaffertium',
#  '10 maccaffertium',
#  '11 maccaffertium',
#  '115 are Maccafertium',
#  '12 are Maccaffertium',
#  '128 are Maccafertium',
#  '13 maccaffertium',
#  '149 are Maccafertium',
#  '15 Maccafertium',
#  '15 are Maccafertium',
#  '16 Maccafertium',
#  '16 are Maccafertium',
#  '16 maccaffertium',
#  '17 are Maccafertium',
#  '18 are Maccafertium',
#  '19 are Maccafertium',
#  '19 immature/damaged',
#  '2',
#  '2 in RC',
#  '2 maccaffertium',
#  '2 specimens in RC',
#  '2 specimens in RC.',
#  '2 specimens in RC. Muscidae, Limnophora',
#  '2 vouchered for gene sequencing',
#  '2 with anal gills',
#  '20 maccaffertium',
#  '22 are Maccafertium',
#  '23 are Maccafertium',
#  '24 are Maccafertium',
#  '24 maccaffertium',
#  '26 are Maccafertium',
#  '260 are Maccafertium',
# ...
